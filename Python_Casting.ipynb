# %% [markdown]
# <a href="https://colab.research.google.com/github/FAYASISMAEL/Python-GoogleCollab-/blob/main/Python_Casting.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
name1 = 'Fayas'
name2 = 'Ismael'
print(name1 + name2)
# Out:
# FayasIsmael

# %%
number1 = '1'
number2 = "2"

print(type(number1))
print(type(number2))

print(number1 + number2)
# Out:
# <class 'str'>
# <class 'str'>
# 12

# %%
n1 = 1
n2 = 2

print(type(n1))
print(type(n2))

print(n1 + n2)
# Out:
# <class 'int'>
# <class 'int'>
# 3

# %%
a = int('5')
b = int('3')
print('out 1 : ')
print(a + b)

c = '5'
d = '3'
print('out 2 : ')
print(c + d)
print('out 3 : ')
print(int(c) + int(d))
# Out:
# out 1 :
# 8
# out 2 :
# 53
# out 3 :
# 8

# %%
def fayas():
  print(input('Enetr you name: '))

fayas()
# Out:
# Enetr you name: fayas
# fayas

# %%
def add_numbers(a, b):
  return a + b

input1 = int(input('Enter your 1st number: '))
input2 = int(input('Enter your 2nd number: '))

result = add_numbers(input1, input2)
print(f'The sum of {input1} and {input2} is: {result}')
# Out:
# Enter your 1st number: 5
# Enter your 2nd number: 6
# The sum of 5 and 6 is: 11

# %%
def odd_number(a):
  if a %2 != 0:
    print(f'{a} is a odd number')
    return a
  else:
    print(f'{a} is not a odd number')

num = int(input('Enter your number: '))

result = odd_number(num)
# Out:
# Enter your number: 3
# 3 is a odd number
