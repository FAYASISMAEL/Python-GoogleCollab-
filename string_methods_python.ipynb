# %% [markdown]
# <a href="https://colab.research.google.com/github/FAYASISMAEL/Python-GoogleCollab-/blob/main/string_methods_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Date: 11-09-2026

# %%
marks = float(input('Enter Your Marks: '))
if marks >= 60:
  print('You are PASSED the exams')
else:
  print('You are FAILED the exams')
# Out:
# Enter Your Marks: 60
# You are PASSED the exams

# %%
b = 'Happy, Birthday'
print(b[2:6])
# Out:
# ppy,

# %%
value = 6
guess = int(input('Enter a value: '))
if value == 6:
  print('Your guess is right, you won a Chocalate.')
else:
  print('Your guess is wrong, thankyou for the participation.')
# Out:
# Enter a value: 6
# Your guess is right, you won a Chocalate.

# %% [markdown]
# palindrome

# %%
text = input('Enter a text: ')

reverse = text[::-1]

if text == reverse:
  print('Palindrome')

else:
  print('not palindrome')
# Out:
# Enter a text: malayalam
# Palindrome

# %% [markdown]
# list

# %%
list = ["Fayas", "Varun", "Athul", "Dhyan"]
print(list)
print(type(list))
# Out:
# ['Fayas', 'Varun', 'Athul', 'Dhyan']
# <class 'list'>
